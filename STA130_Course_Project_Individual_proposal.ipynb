# %% [markdown]
# <a href="https://colab.research.google.com/github/chrislxn/STA130/blob/main/STA130_Course_Project_Individual_proposal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Introduction
# Analysis A: CONNECTION_activities_video_chat_p3m
#
# Analysis B: CONNECTION_activities_text_or_messaged_p3m
#
# Analysis C: CONNECTION_activities_letter_or_email_p3m
#
# Explanation:
#
# Advances in communication technology have now brought people closer together and made it possible for them to communicate across space.
#
# The above three connection methods are the main ways to communicate with friends without meeting them. This project will analyse, compare and discuss the usage of these methods and how they affect the frequency of their communication.
#
# As the statistical data above are similar (Since all datasets are of string type and have the same data structure, the process for these datasets should be generic, So the following process is capable with all the three analysis）

# %% [markdown]
# ### Analysis A

# %%
# Step1: Import the file from Github

import pandas as pd
cols = pd.read_csv("https://raw.githubusercontent.com/pointOfive/stat130chat130/main/CP/var_names.csv")
data = pd.read_csv("https://raw.githubusercontent.com/pointOfive/stat130chat130/main/CP/CSCS_data_anon.csv",
                   na_values=["9999", "", " ", "Presented but no response", "NA"])
empty = (data.isna().sum()==data.shape[0])
data = data[empty.index[~empty]] # keep non empty columns only

data.shape
# Out:
# <ipython-input-28-210cffc185f8>:5: DtypeWarning: Columns (129,408,630,671,689,978,1001,1002,1006,1007,1008,1080,1113,1115,1116,1117,1118,1119,1120,1121,1124,1125,1126,1127,1128,1213,1214,1215,1216,1217,1218,1263,1266,1342,1343,1344,1345,1346,1347,1348,1349,1390,1391,1393,1439,1442,1463,1546,1549,1552,1555,1558,1561) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("https://raw.githubusercontent.com/pointOfive/stat130chat130/main/CP/CSCS_data_anon.csv",
# (11431, 1779)

# %%
# Step2: Filtering and initialize data
# This variable indicates whether the observation was part of the cohort survey or the cross-sectional survey
# All the code below are from oringinal Jupyter file given on the Github
data.SURVEY_collection_type.value_counts()
# Out:
# SURVEY_collection_type
# cross     10563
# cohort      868
# Name: count, dtype: int64

# %%
# This variable indicates whether the observation is from a cohort participant
data.SURVEY_cohort_participant.value_counts()
# Out:
# SURVEY_cohort_participant
# False    10172
# True      1259
# Name: count, dtype: int64

# %%
# This variable indicates the number of observations the participant has
data.SURVEY_num_responses.value_counts()
# Out:
# SURVEY_num_responses
# 1     9828
# 3      691
# 2      418
# 4      407
# 5       58
# 6       19
# 7        9
# 11       1
# Name: count, dtype: int64

# %%
# This variable indicates the unique ID of the participant
data.SURVEY_random_id.notna().value_counts() # few have IDs
# Out:
# SURVEY_random_id
# False    10837
# True       594
# Name: count, dtype: int64

# %%
# This variable indicates cases we recommend removing from an analysis due to fast completion times or possible fraudulent responses.
data.REMOVE_case.value_counts()
# Out:
# REMOVE_case
# No       10018
# Yes       1153
# Maybe      260
# Name: count, dtype: int64

# %%
# Let's just keep the recommended data
dataV2 = data[data.REMOVE_case=='No'].copy()
dataV2.shape
# Out:
# (10018, 1779)

# %%
# And select out participants who are part of the cohort data
# (but may also be a part of the cross-sectional data)
dataV2_cohort = dataV2[dataV2.SURVEY_cohort_participant].copy()
dataV2_cohort.shape
# Out:
# (865, 1779)

# %%
# And remove year 2023 for which there's not yet much data collected
dataV2_cohortV2 = dataV2_cohort[dataV2_cohort.SURVEY_collection_year!=2023].copy()
dataV2_cohortV2.shape
# Out:
# (850, 1779)

# %%
# And remove columns that have less than some number of missing values
# We could consider no missing values using 850, or...?
missingness_limit = 100 # this retains 166 of 1024 columns that aren't fully empty
columns2keep = dataV2_cohortV2.isna().sum() < missingness_limit
columns2keep = columns2keep.index[columns2keep]
dataV2_cohortV3 = dataV2_cohortV2[columns2keep].copy()
dataV2_cohortV3.shape
# Out:
# (850, 166)

# %%
# The data itself then looks like this
pd.set_option('display.max_columns', dataV2_cohortV3.shape[1]) # Can cause jupyter notebooks to crash
# DO NOT USE in conjuection with pd.set_option('display.max_rows', 1000)
dataV2_cohortV3
# Out:
#         UNIQUE_id  UNIQUE_num_records ELIGIBLE_consent  \
# 19     cscs_00021                   3              Yes
# 21     cscs_00021                   3              Yes
# 71     cscs_00074                   3              Yes
# 77     cscs_00080                   2              Yes
# 78     cscs_00080                   2              Yes
# ...           ...                 ...              ...
# 11379  cscs_11760                   3              Yes
# 11380  cscs_11760                   3              Yes
# 11412  cscs_11795                   3              Yes
# 11428  cscs_11812                   3              Yes
# 11430  cscs_11812                   3              Yes
#
#       COVID_prevention_distancing COVID_prevention_masks  \
# 19                   Very closely           Very closely
# 21               Somewhat closely       Somewhat closely
# 71               Somewhat closely       Somewhat closely
# 77               Somewhat closely           Very closely
# ...

# %%
# Step3: Question-relevant data from filtered data
name_only_df = dataV2_cohortV3[['CONNECTION_activities_video_chat_p3m']]
name_only_df
# Out:
#       CONNECTION_activities_video_chat_p3m
# 19                       Less than monthly
# 21            Not in the past three months
# 71                      A few times a week
# 77                       Less than monthly
# 78                       Less than monthly
# ...                                    ...
# 11379                   A few times a week
# 11380                  A few times a month
# 11412                               Weekly
# 11428                   A few times a week
# 11430                Daily or almost daily
#
# [850 rows x 1 columns]

# %% [markdown]
# ### Step4: Count the number of times each option is chosen.
#
# As the form is made up by mutiple choice question, we can count how many time that each of them is chosen and calculate their distribution.

# %% [markdown]
# ### Step5: Data visualisation
# Use a box and whisker plot to visualize the three datasets, compare the distribution of their mean and interquartiles. Examine how the difference between the transmission of information affects the frequency that people contact with others.

# %% [markdown]
# ### Step6: Testing
#
# We assume that the way and efficiency that information transmit does not affects the frequency people using it (H0), and we want to examine if it really happends. So we set our H1 as the way information transmit do affects people's behaviour. If we cannot reject H1, we have to accept H0.
#
# Firstly, we have to transform the strings in the datasets into integers so that we can apply our statistical methods to the sets.
#
# There are several different language people use to describe how often they communicate with others by a method and we have to find out how they represents integers.
#
# For example: "A few times monthly" is above two and less than four (which about to reach once a week)
#
# After we have converted these strings to integers, we can approximate how often they are used and bring them in to the calculation of hypothesis test.

# %% [markdown]
# ### Step7: Summarize the result
#
# From the testing, we could summarize the factors that affects the frequency that people contact others. We can offer some suggestions on how to get people more involved in socialising from our statistical results.
